# %%
from qiskit import QuantumCircuit
from qiskit_aer.primitives import Sampler

# Build a simple circuit
qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

# Use the Sampler primitive
sampler = Sampler()
result = sampler.run(qc, shots=1000).result()

print(result)
# Out:
# SamplerResult(quasi_dists=[{1: 0.508, 0: 0.492}], metadata=[{'shots': 1000, 'simulator_metadata': {'num_bind_params': 1, 'runtime_parameter_bind': False, 'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000119167, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'active_input_qubits': [0], 'device': 'CPU', 'time_taken': 0.0004505, 'measure_sampling': True, 'num_clbits': 1, 'max_memory_mb': 16384, 'input_qubit_map': [[0, 0]], 'num_qubits': 1, 'method': 'stabilizer', 'required_memory_mb': 0, 'fusion': {'enabled': False}}}])
